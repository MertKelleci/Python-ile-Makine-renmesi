# %% [markdown]
# <h1 style="text-align:center;">Support Vector Regression</h1>
#
#
# Scaling is important!

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# veri yukleme
veriler = pd.read_csv('maaslar.csv')

#slicing
x = veriler.iloc[:,1:2]
y = veriler.iloc[:,2:]

#Numpy Array'a dönüştürme
X = x.values
Y = y.values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = x_train.values
Y = y_train.values

sc = StandardScaler()
x_olcekli = sc.fit_transform(X)
sc1 = StandardScaler()
y_olcekli = np.ravel(sc1.fit_transform(Y.reshape(-1,1)))

# %%
from sklearn.svm import SVR
svr_reg = SVR(kernel = 'rbf')

# %%
svr_reg.fit(x_olcekli,y_olcekli)

plt.scatter(x_olcekli,y_olcekli,color='red')
plt.plot(x_olcekli,svr_reg.predict(x_olcekli),color='blue')

# %% [markdown]
# Burada şekil saçma sapan çıktı, yukarıdaki kodu tekrarlamamak için önemli kısmı __03 - Polinom Regresyon (Polynomial Regression)__ dosyasına kaydettim.
